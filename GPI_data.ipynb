# %%
import pandas as pd

file_path = "/Users/liliamn/PycharmProjects/cfg-python/GPI_2022.xlsx"

df = pd.read_excel(file_path)
df
# Out:
#          Country iso3c   2008   2009   2010   2011   2012   2013   2014  \
# 0    Afghanistan   AFG  3.095  3.191  3.040  3.021  3.154  3.258  3.212
# 1        Albania   ALB  1.806  1.779  1.770  1.797  1.799  1.816  1.810
# 2        Algeria   DZA  2.306  2.333  2.333  2.479  2.399  2.383  2.293
# 3         Angola   AGO  2.062  2.066  2.006  2.049  2.087  2.089  2.062
# 4      Argentina   ARG  1.818  1.946  1.947  1.909  1.872  2.001  1.905
# ..           ...   ...    ...    ...    ...    ...    ...    ...    ...
# 158    Venezuela   VEN  2.313  2.359  2.364  2.337  2.284  2.256  2.333
# 159      Vietnam   VNM  1.832  1.846  1.870  1.860  1.923  1.871  1.832
# 160        Yemen   YEM  2.407  2.474  2.562  2.565  2.609  2.547  2.611
# 161       Zambia   ZMB  1.843  1.834  1.827  1.730  1.814  1.728  1.810
# 162     Zimbabwe   ZWE  2.376  2.660  2.732  2.660  2.422  2.395  2.260
#
#       2015   2016   2017   2018   2019   2020   2021   2022
# ...

# %% [markdown]
# The Global Peace Index data is available from 2008 as GPI was launched in 2007.

# %%
# Define the list of countries
countries = ["Chad", "Afghanistan", "Mali", "Niger", "Guinea", "Cuba", "Lithuania", "Estonia", "Latvia", "North Korea"]

# %%
filtered_df = df[df["Country"].isin(countries)]

filtered_df
# Out:
#          Country iso3c   2008   2009   2010   2011   2012   2013   2014  \
# 0    Afghanistan   AFG  3.095  3.191  3.040  3.021  3.154  3.258  3.212
# 26          Chad   TCD  2.785  2.843  2.908  2.668  2.612  2.361  2.438
# 33          Cuba   CUB  2.023  2.017  2.016  1.990  2.032  2.018  1.987
# 45       Estonia   EST  1.689  1.723  1.729  1.701  1.679  1.658  1.553
# 56        Guinea   GIN  2.244  2.261  2.326  2.310  2.174  2.184  2.212
# 79        Latvia   LVA  1.595  1.688  1.666  1.660  1.656  1.596  1.556
# 84     Lithuania   LTU  1.692  1.676  1.683  1.770  1.757  1.709  1.675
# 88          Mali   MLI  2.216  2.232  2.313  2.303  2.313  2.424  2.514
# 103        Niger   NER  2.013  2.091  2.117  2.062  2.057  2.009  1.981
# 105  North Korea   PRK  2.887  2.886  2.935  2.982  2.921  2.935  2.946
#
#       2015   2016   2017   2018   2019   2020   2021   2022
# 0    3.316  3.362  3.412  3.513  3.520  3.592  3.600  3.554
# ...

# %%
filtered_df.columns
# Out:
# Index(['Country',   'iso3c',      2008,      2009,      2010,      2011,
#             2012,      2013,      2014,      2015,      2016,      2017,
#             2018,      2019,      2020,      2021,      2022],
#       dtype='object')

# %%
filtered_df = filtered_df.drop(filtered_df.columns[[1, -1]], axis=1)

filtered_df
# Out:
#          Country   2008   2009   2010   2011   2012   2013   2014   2015  \
# 0    Afghanistan  3.095  3.191  3.040  3.021  3.154  3.258  3.212  3.316
# 26          Chad  2.785  2.843  2.908  2.668  2.612  2.361  2.438  2.454
# 33          Cuba  2.023  2.017  2.016  1.990  2.032  2.018  1.987  1.993
# 45       Estonia  1.689  1.723  1.729  1.701  1.679  1.658  1.553  1.619
# 56        Guinea  2.244  2.261  2.326  2.310  2.174  2.184  2.212  2.196
# 79        Latvia  1.595  1.688  1.666  1.660  1.656  1.596  1.556  1.609
# 84     Lithuania  1.692  1.676  1.683  1.770  1.757  1.709  1.675  1.691
# 88          Mali  2.216  2.232  2.313  2.303  2.313  2.424  2.514  2.589
# 103        Niger  2.013  2.091  2.117  2.062  2.057  2.009  1.981  2.237
# 105  North Korea  2.887  2.886  2.935  2.982  2.921  2.935  2.946  2.954
#
#       2016   2017   2018   2019   2020   2021
# 0    3.362  3.412  3.513  3.520  3.592  3.600
# 26   2.414  2.523  2.441  2.499  2.549  2.578
# ...

# %%
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
#        Country   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0  Afghanistan  3.095  3.191  3.040  3.021  3.154  3.258  3.212  3.316  3.362
# 1         Chad  2.785  2.843  2.908  2.668  2.612  2.361  2.438  2.454  2.414
# 2         Cuba  2.023  2.017  2.016  1.990  2.032  2.018  1.987  1.993  1.975
# 3      Estonia  1.689  1.723  1.729  1.701  1.679  1.658  1.553  1.619  1.598
# 4       Guinea  2.244  2.261  2.326  2.310  2.174  2.184  2.212  2.196  2.166
# 5       Latvia  1.595  1.688  1.666  1.660  1.656  1.596  1.556  1.609  1.562
# 6    Lithuania  1.692  1.676  1.683  1.770  1.757  1.709  1.675  1.691  1.701
# 7         Mali  2.216  2.232  2.313  2.303  2.313  2.424  2.514  2.589  2.520
# 8        Niger  2.013  2.091  2.117  2.062  2.057  2.009  1.981  2.237  2.194
# 9  North Korea  2.887  2.886  2.935  2.982  2.921  2.935  2.946  2.954  2.922
#
#     2017   2018   2019   2020   2021
# 0  3.412  3.513  3.520  3.592  3.600
# ...

# %%
filtered_df['Mean'] = filtered_df.iloc[:, 1:].mean(axis=1)
filtered_df
# Out:
#        Country   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0  Afghanistan  3.095  3.191  3.040  3.021  3.154  3.258  3.212  3.316  3.362
# 1         Chad  2.785  2.843  2.908  2.668  2.612  2.361  2.438  2.454  2.414
# 2         Cuba  2.023  2.017  2.016  1.990  2.032  2.018  1.987  1.993  1.975
# 3      Estonia  1.689  1.723  1.729  1.701  1.679  1.658  1.553  1.619  1.598
# 4       Guinea  2.244  2.261  2.326  2.310  2.174  2.184  2.212  2.196  2.166
# 5       Latvia  1.595  1.688  1.666  1.660  1.656  1.596  1.556  1.609  1.562
# 6    Lithuania  1.692  1.676  1.683  1.770  1.757  1.709  1.675  1.691  1.701
# 7         Mali  2.216  2.232  2.313  2.303  2.313  2.424  2.514  2.589  2.520
# 8        Niger  2.013  2.091  2.117  2.062  2.057  2.009  1.981  2.237  2.194
# 9  North Korea  2.887  2.886  2.935  2.982  2.921  2.935  2.946  2.954  2.922
#
#     2017   2018   2019   2020   2021      Mean
# 0  3.412  3.513  3.520  3.592  3.600  3.306143
# ...

# %%
gpi = filtered_df[['Country', 'Mean']]
gpi
# Out:
#        Country      Mean
# 0  Afghanistan  3.306143
# 1         Chad  2.576643
# 2         Cuba  2.001071
# 3      Estonia  1.632643
# 4       Guinea  2.165071
# 5       Latvia  1.611214
# 6    Lithuania  1.691786
# 7         Mali  2.494071
# 8        Niger  2.225214
# 9  North Korea  2.931000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(gpi['Country'], gpi['Mean'], color='green')
plt.xlabel('Country')
plt.ylabel('Mean')
plt.title('Mean GPI')
plt.xticks(rotation=90)
plt.show()
